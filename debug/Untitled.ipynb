# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.arange(-20,20,0.01)

# %%
plt.hist(np.exp(x))
# Out:
# (array([3769.,   70.,   40.,   29.,   22.,   18.,   16.,   13.,   12.,
#           11.]),
#  array([2.06115362e-09, 4.80337721e+07, 9.60675442e+07, 1.44101316e+08,
#         1.92135088e+08, 2.40168861e+08, 2.88202633e+08, 3.36236405e+08,
#         3.84270177e+08, 4.32303949e+08, 4.80337721e+08]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x, np.exp(x))
